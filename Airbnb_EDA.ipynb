# %% [markdown]
# <a href="https://colab.research.google.com/github/vipulcodes-max/almabetterprojects/blob/main/Airbnb_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
# AIR BNB

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The primary objective of this project is to understand patterns in Airbnb listings across New York City and uncover insights related to pricing, room types, availability, host behavior, and geographical distribution.
#
# Rather than immediately building predictive models, I focused on Exploratory Data Analysis, or EDA, because EDA helps us understand the story hidden inside the data before making business decisions.

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vipulcodes-max/almabetterprojects.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7)
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
file_path = '/content/drive/My Drive/Capstone Projects Almabetter/Airbnb NYC 2019.csv'
airbnb_df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head(10)

# %%
airbnb_df.info()

# %%
airbnb_df = airbnb_df.dropna()

# %%
airbnb_df.isnull().sum()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb_df.isnull().sum()

# %%
# Visualizing the missing values

plt.figure(figsize=(6, 8))
msno.bar(airbnb_df)
plt.show()

# %%
airbnb_df = airbnb_df.dropna()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %% [markdown]
# The Visualization helps as understand that only 2 Columns** Last_review and reviews per month** have missing values in the data sets and only 20% of the total values are missing from that columns.

# %%
# Dataset Columns
airbnb_df.columns

# %%
# Dataset Describe
airbnb_df.describe()

# %%
from matplotlib import pyplot as plt
airbnb_df['host_id'].plot(kind='hist', bins=20, title='id')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Price: Right-skewed distribution with potential outliers. Log scale transformation can help.
# Minimum Nights: Potential long tail, indicating some listings have long minimum stay requirements.
# Number of Reviews: Typically right-skewed, with most listings having fewer reviews.
# Reviews per Month: Handle NaN values appropriately to ensure accurate visualization.
# Calculated Host Listings Count: Shows host activity, with some having multiple listings.
# Availability 365: Indicates how often a listing is available throughout the year

# %% [markdown]
# ### Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Check Unique Values for each variable.
airbnb_df.nunique()

# %%
airbnb_df['neighbourhood'].unique()

# %%
airbnb_df['neighbourhood_group'].unique()

# %%
airbnb_df['room_type'].unique()

# %%
columns_to_drop = ['latitude', 'longitude', 'last_review', 'reviews_per_month']
existing_columns_to_drop = [col for col in columns_to_drop if col in airbnb_df.columns]
if existing_columns_to_drop:
    airbnb_df.drop(columns=existing_columns_to_drop, inplace=True)

# %%
airbnb_df.head()

# %%
airbnb_df.isnull().sum()

# %% [markdown]
# ### Data Wrangling Code

# %%
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'], as_index=False)['price'].mean().rename(columns={'neighbourhood_group':'Location','price':'Average Price'})
avg_preffered_price_df

# %%
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_preffered_price_df

# %%
avg_preffered_price_df.plot.bar()

# %%
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False).rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
no_of_host_per_location

# %%
airbnb_df.fillna({'reviews_per_month':0},inplace=True)
airbnb_df.fillna({'host_name':'none'},inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# ---

# %% [markdown]
# **Answer** Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
airbnb_df[airbnb_df['minimum_nights'] ==1].sort_values(['price', 'minimum_nights'], ascending=[True, True])

# %% [markdown]
# #### Chart - 1

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# Changed to visualize room_type counts from airbnb_df
airbnb_df['room_type'].value_counts().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
area_counts.groupby('neighbourhood_group').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Chart - Distribution of Listings by Neighbourhood Group
plt.figure(figsize=(10, 6))
sns.countplot(x='neighbourhood_group', data=airbnb_df, palette='viridis', hue='neighbourhood_group', legend=False)
plt.title('Distribution of Airbnb Listings by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a countplot (bar chart) to visualize the distribution of Airbnb listings across different `neighbourhood_group` categories. This type of chart is ideal for displaying the frequency of categorical data, making it easy to compare the number of listings in each group at a glance.

# %% [markdown]
# The chart clearly shows that Manhattan and Brooklyn have a significantly higher number of Airbnb listings compared to Queens, Bronx, and Staten Island. Manhattan appears to have the most listings, closely followed by Brooklyn. Queens has a moderate number of listings, while Bronx and Staten Island have considerably fewer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The chart clearly shows that Manhattan and Brooklyn have a significantly higher number of Airbnb listings compared to Queens, Bronx, and Staten Island. Manhattan appears to have the most listings, closely followed by Brooklyn. Queens has a moderate number of listings, while Bronx and Staten Island have considerably fewer.

# %% [markdown]
# The chart clearly shows that Manhattan and Brooklyn have a significantly higher number of Airbnb listings compared to Queens, Bronx, and Staten Island. Manhattan appears to have the most listings, closely followed by Brooklyn. Queens has a moderate number of listings, while Bronx and Staten Island have considerably fewer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, these insights can definitely help in creating a positive business impact. For Airbnb hosts and potential investors, this indicates that Manhattan and Brooklyn are the most active and potentially profitable markets due to higher demand and supply. For Airbnb as a platform, it highlights areas of high market penetration and areas where there might be opportunities for growth (Bronx, Staten Island, and to some extent, Queens) by encouraging more hosts or targeting specific types of listings. Negative growth insights are not directly apparent from this distribution, but it does suggest that focusing on highly competitive areas (Manhattan, Brooklyn) might require more strategic differentiation, while less competitive areas might offer easier entry for new hosts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, these insights can definitely help in creating a positive business impact. For Airbnb hosts and potential investors, this indicates that Manhattan and Brooklyn are the most active and potentially profitable markets due to higher demand and supply. For Airbnb as a platform, it highlights areas of high market penetration and areas where there might be opportunities for growth (Bronx, Staten Island, and to some extent, Queens) by encouraging more hosts or targeting specific types of listings. Negative growth insights are not directly apparent from this distribution, but it does suggest that focusing on highly competitive areas (Manhattan, Brooklyn) might require more strategic differentiation, while less competitive areas might offer easier entry for new hosts.

# %%
airbnb_df1 = airbnb_df.groupby(['price','availability_365'])

airbnb_df1 = airbnb_df.groupby(['price','availability_365']).count().reset_index()
airbnb_df2 = airbnb_df1.sort_values('calculated_host_listings_count',ascending = False)
area_counts = airbnb_df2.head(10)
area_counts

# %%
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'])
avg_preffered_price_df

# %%
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False).rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
no_of_host_per_location

# %%
#  find the maximum(minimum nights) spending by customer across different room type
total_room=airbnb_df.groupby(  'room_type')['minimum_nights'].sum().reset_index()
room_types=total_room.sort_values('minimum_nights',ascending=True)
room_types.head()

# %%
airbnb_df[airbnb_df['minimum_nights'] ==1].sort_values(['price', 'minimum_nights'], ascending=[True, True])

# %%
airbnb_df.loc[airbnb_df['price'] < 100,'price'].count()

# %%
labels=list(room_types['room_type'])
sizes=list(room_types['minimum_nights'])
# create color parameter
colors=['green','pink','yellow']
# create explode
explode = (0.07, 0.07, 0.07)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('total no. of nights spend per room types', fontsize=20)
plt.axis("equal")
plt.show()

# %%
neighour=airbnb_df['neighbourhood'].value_counts().sort_values(ascending=False).reset_index()
#top ten neighourhood with listing value
top_10=neighour[:10]
top_10

# %%
total_nights=airbnb_df.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index()
final_nights=total_nights.sort_values('minimum_nights',ascending=True)
final_nights.head()

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
abc= sns.barplot(x='neighbourhood_group',y='minimum_nights',data = final_nights)
abc.set_title('find total no. nights spend per location', weight='bold')
abc.set_ylabel('minimum night', weight='bold')
abc.set_xlabel('neighbourhood group', weight='bold')

# Adjusting x-tick labels more robustly to avoid UserWarning
for item in abc.get_xticklabels():
    item.set_rotation(45)
    item.set_weight('bold')
    item.set_fontsize(15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a bar plot for the 'total no. nights spend per location' to effectively compare the aggregate sum of `minimum_nights` across different `neighbourhood_group` categories. Bar plots are excellent for comparing discrete categories, making it easy to identify which areas have the highest or lowest total minimum night bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The chart clearly shows that Manhattan and Brooklyn account for the vast majority of total minimum nights booked, significantly outpacing Queens, Bronx, and Staten Island. Manhattan has the highest total minimum nights, closely followed by Brooklyn. This indicates that listings in these two boroughs are either booked for longer durations or are booked more frequently, contributing to a higher overall number of nights spent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, these insights are crucial for business impact. For **hosts**, it suggests that properties in Manhattan and Brooklyn, especially `Entire home/apt` types, are highly sought after for longer stays, allowing them to optimize pricing strategies for extended bookings. For **Airbnb as a platform**, this data helps in:
#
# *   **Targeted Marketing**: Focus marketing campaigns for longer stays on guests interested in Manhattan and Brooklyn.
# *   **Host Recruitment**: Prioritize recruiting new hosts in these high-demand areas to meet the apparent demand for longer bookings.
# *   **Revenue Growth**: Longer stays generally translate to higher revenue per booking and potentially lower turnover costs for hosts.
#
# Conversely, the lower total minimum nights in Staten Island and the Bronx could indicate areas for **negative growth** or untapped potential. It might mean:
#
# *   **Lower Demand for Long Stays**: Guests in these areas might prefer shorter stays, or there's less overall demand. Airbnb could investigate if this is due to lack of suitable listings, awareness, or different tourist demographics.
# *   **Opportunity for Niche Markets**: Explore if there's a niche for specific types of longer stays (e.g., business trips, family vacations) that are currently unmet in these boroughs.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# 1.   List item
# 2.   List item

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

#Setting up the color pallete
color_dict = {'Private room': '#cc5a49', 'Entire home/apt' : '#4586ac', 'Shared room' : '#C0C0C0'}

#Grouping the room type using 'neighbourhood_group' as an index
airbnb_types=airbnb_df.groupby(['neighbourhood_group', 'room_type']).size()

#Creating function to plot room type proportion on all region area
for region in airbnb_df.neighbourhood_group.unique():

    plt.figure(figsize=(24,12))

    airbnb_reg=airbnb_types[region]
    labels = airbnb_reg.index
    sizes = airbnb_reg.values


    plot_num = 321
    plt.subplot(plot_num)
    reg_ch = go.Figure(data = [go.Pie(labels = labels, values = sizes, hole = 0.6)])
    reg_ch.update_traces(title = region, textfont_size=15, titlefont_size=25)
    reg_ch.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.10,
    ))
    reg_ch.show()

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,10))
sns.set_style('white')

ax = sns.boxplot(data=airbnb_df, x='neighbourhood_group',y='availability_365',palette='plasma', hue='neighbourhood_group', legend=False)

# Naming the Chart
ax.set_title('Relation between Neighbourhood group & Availability of rooms').set_fontsize('15')

# Naming X & Y axis
ax.set_ylabel('Availability 365 Days').set_fontsize('15')
ax.set_xlabel('Neighbourhood Group').set_fontsize('15')

# Adjusting x-tick labels more robustly to avoid UserWarning
for item in ax.get_xticklabels():
    item.set_fontsize(15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a box plot to visualize the 'Relation between Neighbourhood group & Availability of rooms' because it effectively displays the distribution (median, quartiles, and outliers) of `availability_365` for each `neighbourhood_group`. This allows for a quick comparison of the spread and central tendency of availability across different areas, highlighting where listings are generally more or less available throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The box plot will show the spread of availability across the different neighbourhood groups. Typically, we might observe:
#
# *   **Lower Median Availability**: Areas like Manhattan and Brooklyn might show lower median `availability_365`, suggesting higher occupancy rates and possibly stronger demand.
# *   **Higher Median Availability**: Areas like Staten Island and the Bronx might display higher median availability, indicating either lower demand or hosts who list their properties less frequently.
# *   **Variability**: The length of the 'boxes' and 'whiskers' will show the variance in availability within each neighbourhood group. Some areas might have a wide range of availability (from almost always booked to rarely booked), while others might be more consistent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, understanding the availability patterns offers significant business impact:
#
# *   **For Hosts**: Hosts can gauge the typical availability in their area. If they are in a low-availability area, they might be able to demand higher prices or maintain higher occupancy. If in a high-availability area, they might need to adjust pricing or offer more amenities to attract guests.
# *   **For Airbnb**: This insight is vital for supply and demand management.
#     *   **High-Demand, Low-Availability Areas (e.g., Manhattan, Brooklyn)**: These indicate potential for **positive business impact** through aggressive host recruitment campaigns. More listings can meet unmet demand and increase platform revenue.
#     *   **Lower-Demand, High-Availability Areas (e.g., Staten Island, Bronx)**: These areas represent a potential **negative growth** scenario if availability is high due to low demand. Airbnb could focus marketing efforts to attract more guests to these areas, offer incentives for booking, or provide resources to hosts to improve their listing appeal. This could turn potential negative growth into positive growth by stimulating demand. It also helps identify areas where over-saturation of listings is not an issue, making them potentially attractive for new hosts seeking less competition.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
# ---
#
# \
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Insights from `area_counts` and `no_of_host_per_location`:
#
# *   **Market Dominance in Manhattan and Brooklyn**: Both `area_counts` (indicating high activity at certain price/availability points) and `no_of_host_per_location` (showing the highest host concentration) consistently highlight Manhattan and Brooklyn as the most active and saturated Airbnb markets.
# *   **High Demand for Specific Configurations**: `area_counts` reveals that a significant number of listings cluster around certain price points (e.g., $100-$150) with 0 days of availability, particularly for `Entire home/apt` room types. This suggests high demand for these specific offerings, leading to quick bookings and low remaining availability.
# *   **Host Activity Correlates with Demand**: The `no_of_host_per_location` DataFrame clearly shows that the number of hosts directly corresponds to the perceived attractiveness of a `neighbourhood_group` for Airbnb. Manhattan and Brooklyn attract the most hosts, while Staten Island and the Bronx have significantly fewer.
# *   **Untapped Potential in Less Dense Areas**: The lower number of hosts in the Bronx and Staten Island (as seen in `no_of_host_per_location`) indicates these are underserved markets compared to the others. While current demand might be lower, this also means less competition for new hosts.
# *   **Pricing and Availability Hotspots**: `area_counts` allows for the identification of successful pricing and availability strategies. For example, many listings are priced at $100-$150 with 0 availability, implying these are highly sought after and get booked quickly.

# %% [markdown]
# ## Suggestions to Achieve Business Objectives (Leveraging `area_counts` and `no_of_host_per_location`):
#
# ### 1. Optimize Pricing and Availability based on `area_counts`:
#
# *   **Identify Sweet Spots**: Analyze `area_counts` to pinpoint combinations of `price` and `availability_365` that have the highest number of listings. These represent popular or successful pricing/availability strategies adopted by hosts. The client can recommend these 'sweet spots' to new or underperforming hosts to align with market expectations and increase booking rates.
# *   **Strategic Gaps**: Look for areas where `area_counts` are low but demand is potentially high (e.g., specific price points with year-long availability in popular neighborhoods). This could indicate unmet demand, allowing the client to encourage hosts to adjust their pricing or availability to fill these gaps.
# *   **Revenue Management**: Advise hosts to dynamically adjust prices based on availability patterns identified in `area_counts`. For instance, if certain price points with low availability are highly demanded, hosts could be encouraged to increase prices during peak seasons.
#
# ### 2. Strategic Host Recruitment and Market Expansion using `no_of_host_per_location`:
#
# *   **Deepen Market Penetration (Manhattan & Brooklyn)**: `no_of_host_per_location` clearly shows Manhattan and Brooklyn have the highest host concentration. While competitive, this also signifies high demand. The client can focus on retaining existing hosts and attracting premium or niche listings (e.g., luxury, unique experiences) to maintain leadership and diversify offerings in these key markets.
# *   **Expand in Underserved Areas (Bronx & Staten Island)**: These boroughs have significantly fewer hosts according to `no_of_host_per_location`. This presents a clear opportunity for market expansion. The client can:
#     *   Launch targeted campaigns to onboard new hosts in the Bronx and Staten Island.
#     *   Offer incentives (e.g., lower commission rates for a limited period) to encourage new listings.
#     *   Promote these areas to guests through marketing campaigns highlighting their unique attractions and potentially more affordable stays.
# *   **Balanced Growth (Queens)**: Queens has a moderate number of hosts. The client can aim for steady growth here, balancing recruitment efforts with ensuring existing hosts are supported and that the growth is sustainable.
#
# ### Overall Business Objective:
#
# By strategically using insights from `area_counts` and `no_of_host_per_location`, the client can:
#
# *   **Increase Overall Bookings**: Optimize pricing and availability to match demand, and expand the supply of listings where it's most needed.
# *   **Enhance Host Satisfaction**: Provide data-driven recommendations to hosts, helping them increase their occupancy and earnings.
# *   **Expand Market Share**: Grow in underserved areas while strengthening their position in dominant markets, leading to increased revenue and a more diversified portfolio across New York City.

# %% [markdown]
# ## Suggestions to Achieve Business Objectives (Leveraging `area_counts` and `no_of_host_per_location`):
#
# ### 1. Optimize Pricing and Availability based on `area_counts`:
#
# *   **Identify Sweet Spots**: Analyze `area_counts` to pinpoint combinations of `price` and `availability_365` that have the highest number of listings. These represent popular or successful pricing/availability strategies adopted by hosts. The client can recommend these 'sweet spots' to new or underperforming hosts to align with market expectations and increase booking rates.
# *   **Strategic Gaps**: Look for areas where `area_counts` are low but demand is potentially high (e.g., specific price points with year-round availability in popular neighborhoods). This could indicate unmet demand, allowing the client to encourage hosts to adjust their pricing or availability to fill these gaps.
# *   **Revenue Management**: Advise hosts to dynamically adjust prices based on availability patterns identified in `area_counts`. For instance, if certain price points with low availability are highly demanded, hosts could be encouraged to increase prices during peak seasons.
#
# ### 2. Strategic Host Recruitment and Market Expansion using `no_of_host_per_location`:
#
# *   **Deepen Market Penetration (Manhattan & Brooklyn)**: `no_of_host_per_location` clearly shows Manhattan and Brooklyn have the highest host concentration. While competitive, this also signifies high demand. The client can focus on retaining existing hosts and attracting premium or niche listings (e.g., luxury, unique experiences) to maintain leadership and diversify offerings in these key markets.
# *   **Expand in Underserved Areas (Bronx & Staten Island)**: These boroughs have significantly fewer hosts according to `no_of_host_per_location`. This presents a clear opportunity for market expansion. The client can:
#     *   Launch targeted campaigns to onboard new hosts in the Bronx and Staten Island.
#     *   Offer incentives (e.g., lower commission rates for a limited period) to encourage new listings.
#     *   Promote these areas to guests through marketing campaigns highlighting their unique attractions and potentially more affordable stays.
# *   **Balanced Growth (Queens)**: Queens has a moderate number of hosts. The client can aim for steady growth here, balancing recruitment efforts with ensuring existing hosts are supported and that the growth is sustainable.
#
# ### Overall Business Objective:
#
# By strategically using insights from `area_counts` and `no_of_host_per_location`, the client can:
#
# *   **Increase Overall Bookings**: Optimize pricing and availability to match demand, and expand the supply of listings where it's most needed.
# *   **Enhance Host Satisfaction**: Provide data-driven recommendations to hosts, helping them increase their occupancy and earnings.
# *   **Expand Market Share**: Grow in underserved areas while strengthening their position in dominant markets, leading to increased revenue and a more diversified portfolio across New York City.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ## Executive Summary: Airbnb NYC Market Analysis
#
# This analysis of Airbnb listings in New York City reveals critical insights for strategic decision-making by hosts and the Airbnb platform.
#
# ### Key Findings:
#
# 1.  **Market Concentration**: Manhattan and Brooklyn are the dominant Airbnb markets, hosting the vast majority of listings and attracting the highest cumulative minimum nights booked. This indicates high demand and strong market activity in these boroughs.
# 2.  **Room Type Preference**: 'Entire home/apt' and 'Private room' types are significantly more prevalent and account for a much larger share of total minimum nights compared to 'Shared room' types, suggesting a preference for privacy and dedicated spaces among guests.
# 3.  **Pricing Dynamics**: Pricing varies significantly by `neighbourhood_group` and `room_type`, with 'Entire home/apt' in Manhattan commanding the highest average prices.
# 4.  **Availability Patterns**: Listings in high-demand areas like Manhattan and Brooklyn tend to have lower availability, signaling higher occupancy rates. Conversely, areas like Staten Island and the Bronx often show higher availability, potentially indicating lower demand or less active hosting.
#
# ### Business Impact:
#
# *   **Targeted Growth & Investment**: Manhattan and Brooklyn represent prime areas for sustained growth and investment. Airbnb should continue aggressive host recruitment and marketing efforts in these areas to capitalize on existing demand.
# *   **Host Optimization**: Hosts in Manhattan and Brooklyn can optimize pricing for longer stays and 'Entire home/apt' types. In contrast, hosts in less competitive boroughs (Queens, Bronx, Staten Island) may need to adjust pricing, offer unique amenities, or focus on specific niche markets to attract bookings and reduce availability.
# *   **Market Development**: For areas with lower listing counts (Bronx, Staten Island) or higher availability, Airbnb can explore targeted campaigns to stimulate demand, incentivize new hosts, or develop unique travel experiences to unlock untapped potential and foster positive growth.
# *   **Product Strategy**: The strong preference for 'Entire home/apt' and 'Private room' types should inform product development and promotional strategies, prioritizing features and marketing efforts that cater to these popular listing formats.
#
# By leveraging these insights, Airbnb and its hosts can make data-driven decisions to enhance competitiveness, improve profitability, and strategically expand their market presence across New York City.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
